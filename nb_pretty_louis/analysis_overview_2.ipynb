# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from sklearn.preprocessing import MinMaxScaler
mm = MinMaxScaler()
warnings.simplefilter('ignore')
DATA_PATH = "/media/maxine/c8f4bcb2-c1fe-4676-877d-8e476418f5e5/0-RPE-cell-timelapse/"

# %% [markdown]
# <h1 style = "font-size: 42px; text-align: center;"> Analysis Overview </h1>
# <h2 style = "text-align: center;"> Exploring the cell cycle time series data, fluorescent channels and the drug response </h2>

# %%
control_mm = pd.DataFrame(columns=['y'], dtype='object')
for idx, track in enumerate(os.listdir(DATA_PATH + 'track_datasets/control_mm/train/labels/')):
    control_mm.at[idx, 'y'] = np.load(DATA_PATH + 'track_datasets/control_mm/train/labels/' + track).reshape(2, -1).T
y = np.concatenate(control_mm.y.tolist())
control_mm.shape, y.shape
# Out:
# ((5189, 1), (1195197, 2))

# %%
plt.hexbin(y[:, 0] ,y[:, 1], bins='log', gridsize=(300, 300))

# %%
plt.hexbin(y[:, 0] ,y[:, 1], bins='log', gridsize=(300, 300))
